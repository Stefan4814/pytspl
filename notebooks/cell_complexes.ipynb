# %%
from pytspl import CCPlot
from pytspl.io.data_loaders.paper_loader import load_paper_data_cc

cc, coordinates, flow = load_paper_data_cc()
print(cc.edges)


ccplot = CCPlot(cell_complex=cc, coordinates=coordinates)
ccplot.draw_network()
# Out:
# [(0, 1), (0, 2), (0, 3), (1, 2), (2, 3), (2, 5), (3, 4), (4, 5), (4, 6), (5, 6)]
