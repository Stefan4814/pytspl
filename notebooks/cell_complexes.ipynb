# %%
from pytspl import CCPlot
from pytspl.io.data_loaders.paper_loader import load_paper_data_cc

cc = load_paper_data_cc()

ccplot = CCPlot(cell_complex=cc)

ccplot.draw_network
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/Users/stefan4814/pytspl/pytspl-env/lib/python3.13/site-packages/IPython/core/interactiveshell.py", line 3549, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#     ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/z8/m737xwzs7xb8w1vslt025hnc0000gn/T/ipykernel_52837/1756608243.py", line 1, in <module>
#     from pytspl import CCPlot
# ImportError: cannot import name 'CCPlot' from 'pytspl' (/Users/stefan4814/pytspl/pytspl-env/lib/python3.13/site-packages/pytspl/__init__.py). Did you mean: 'SCPlot'?
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/stefan4814/pytspl/pytspl-env/lib/python3.13/site-packages/IPython/core/interactiveshell.py", line 2173, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
# ...

# %%
import pytspl.plot
print(dir(pytspl.plot))
# Out:
# ['SCPlot', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', 'plot']

# %%
import importlib
import pytspl.plot

importlib.reload(pytspl.plot)
print(dir(pytspl.plot))
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/Users/stefan4814/pytspl/pytspl-env/lib/python3.13/site-packages/IPython/core/interactiveshell.py", line 3549, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#     ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/z8/m737xwzs7xb8w1vslt025hnc0000gn/T/ipykernel_54541/2771622610.py", line 4, in <module>
#     importlib.reload(pytspl.plot)
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/importlib/__init__.py", line 128, in reload
#     raise ModuleNotFoundError(f"spec not found for the module {name!r}", name=name)
# ModuleNotFoundError: spec not found for the module 'pytspl.plot'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# ...
