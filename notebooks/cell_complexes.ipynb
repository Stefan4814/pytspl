# %%
from pytspl import SCPlot
from pytspl.io.data_loaders.paper_loader import load_paper_data

cc, coordinates, flow = load_paper_data(=False)
print(cc.edges)


ccplot = SCPlot(complex=cc, coordinates=coordinates, plot_sc=False)
ccplot.draw_network()

# %%
from pytspl import SCPlot
from pytspl import list_datasets, load_dataset
import matplotlib.pyplot as plt
list_datasets()

dataset = "wsn"
sc, coordinates, flow = load_dataset(dataset=dataset, only_sc=False)

scplot = SCPlot(complex=sc, coordinates=coordinates, only_sc=False)
# scplot.draw_network()
# Out:
# WARNING: No coordinates found.
# Generating coordinates using spring layout.
# Num. of nodes: 114
# Num. of edges: 164
# Num. of triangles: 51
# Coordinates: 114
# Flow: 278

# %%
from pytspl.io.data_loaders.webkb_loader import load_webkb_data

graphs = load_webkb_data()
for name, G in graphs.items():
    print(f"{name}: nodes = {G.number_of_nodes()}, edges = {G.number_of_edges()}")
# Out:
# cornell: nodes = 183, edges = 280
# texas: nodes = 183, edges = 295
# wisconsin: nodes = 251, edges = 466

# %%
from pytspl.io.data_loaders.webkb_loader import load_webkb_data

graphs = load_webkb_data()
for name, G in graphs.items():
    print(f"{name}: nodes = {G.number_of_nodes()}, edges = {G.number_of_edges()}")
