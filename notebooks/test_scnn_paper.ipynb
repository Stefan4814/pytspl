# %%
from pytspl import list_datasets, load_dataset, SCPlot, SimplicialComplex
import numpy as np
import matplotlib.pyplot as plt

# list all the datasets
list_datasets()
# Out:
# ['barcelona',
#  'chicago-regional',
#  'siouxfalls',
#  'anaheim',
#  'test_dataset',
#  'goldcoast',
#  'winnipeg',
#  'chicago-sketch',
#  'paper',
#  'forex',
#  'lastfm-1k-artist',
#  'webkb-cornell',
#  'webkb-texas',
#  'webkb-wisconsin',
#  'wsn',
#  'scnn_paper']

# %%
dataset = "scnn_paper"
sc, coordinates, flow = load_dataset(dataset=dataset, only_2d=False)
# Out:
# WARNING: No coordinates found.
# Generating coordinates using spring layout.
# Num. of 0-simplices: 352
# Num. of 1-simplices: 1474
# Num. of 2-simplices: 3285
# Num. of 3-simplices: 5019
# Num. of 4-simplices: 5559
# Num. of 5-simplices: 4547
# Num. of 6-simplices: 2732
# Num. of 7-simplices: 1175
# Num. of 8-simplices: 343
# Num. of 9-simplices: 61
# Num. of 10-simplices: 5
# Shape: (352, 1474, 3285, 5019, 5559, 4547, 2732, 1175, 343, 61, 5)
# Max Dimension: 10
# Coordinates: 352
# Flow: 0
